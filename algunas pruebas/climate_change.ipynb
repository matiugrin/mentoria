# %%
import json
import pandas as pd
# import io, bson, multiprocessing
import bson

# %%
with open('climate-change/users.bson','rb') as b:
    df = pd.DataFrame(bson.decode_all(b.read()))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-2d12c57be6ca> in <module>()
# ----> 1 with open('climate-change/users.bson','rb') as b:
#       2     df = pd.DataFrame(bson.decode_all(b.read()))
#
# FileNotFoundError: [Errno 2] No such file or directory: 'climate-change/users.bson'

# %%
df
# Out:
#                              _id                   id               id_str  \
# 0       5dfd3d4d74e5f1ecede595b1   833314823685361664   833314823685361664
# 1       5dfd3d4d74e5f1ecede595b3           4824238951           4824238951
# 2       5dfd3d4d74e5f1ecede595b5   998910748054179840   998910748054179840
# 3       5dfd3d4d74e5f1ecede595b7  1201199960903094273  1201199960903094273
# 4       5dfd3d4e74e5f1ecede595b9             16996451             16996451
# ...                          ...                  ...                  ...
# 376584  5e0a51a6f8390d4ea29139c8  1005576270934093824  1005576270934093824
# 376585  5e0a51a7f8390d4ea29139ce           1305935082           1305935082
# 376586  5e0a51a9f8390d4ea29139e2             49897139             49897139
# 376587  5e0a51a9f8390d4ea29139e6   808545586035060737   808545586035060737
# 376588  5e0a51aaf8390d4ea29139ea            416903487            416903487
#
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
with open('/content/drive/My Drive/Machine Learning/Mentoria/datos/feminism/feminism.bson','rb') as b:
  # line = pd.DataFrame(bson.decode_all(b.readline()))
  line = b.readlines()
    # df_climate = pd.DataFrame(bson.decode_all(b.read(chunksize=50)))

# %%
line

# %%
bson.decode_all?
